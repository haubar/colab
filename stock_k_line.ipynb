# %% [markdown]
# <a href="https://colab.research.google.com/github/haubar/colab/blob/main/stock_k_line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import yfinance as yf
plt.style.use('fivethirtyeight')

# %%
#股票代號
#美股: TSLA , AAPL , GOOG 直接用股價代號
#台股: 2330.TW , 3008.TW , 2317.TW 以此類推
stock_no='3231.TW'
#起始日期
start_date='2021-01-01'
# end_date='2024-06-19'
#下載資料 省略 end 會自動抓到最近的交易日期
df=yf.download(stock_no,start=start_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2024-06-13  107.0  109.0  107.0  108.5      108.5  37659962
# 2024-06-14  109.0  109.5  107.0  108.5      108.5  35237661
# 2024-06-17  108.5  108.5  106.0  106.5      106.5  26488749
# 2024-06-18  107.5  108.0  106.5  107.0      107.0  24984377
# 2024-06-19  107.5  112.0  107.5  111.0      111.0  96500938

# %%
# 圖表產生
figure = go.Figure(
    data=[
          go.Candlestick(
              x=df.index,

              open=df['Open'],
              high=df['High'],
              low=df['Low'],
              close=df['Close'],
              increasing_line_color='red',
              decreasing_line_color='green'
          )
    ]
)
#figure.update_layout(xaxis_rangeslider_visible=False)
figure.update_layout(
    title='3231 價格',
    xaxis_title='日期',
    yaxis_title='價格',
)

#秀圖
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
